# %%
import pandas as pd
import matplotlib.pyplot as plt
from customplotting.general import plot_xy, save_fig

# %% [markdown]
# # 02/10/2021 --> SnGe NCs

# %%
SnGe_4500rpm= pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/UV-Vis/2021_02_10/SNGE_NPs_4500rpm_45nmF.CSV')
SnGe_11000rpm = pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/UV-Vis/2021_02_10/SNGE_NPs_11000rpm_300rpms_45nmF.CSV')

# %%
plt.plot(SnGe_4500rpm['Wavelength (nm)'].values, SnGe_4500rpm['Absorbance (AU)'].values, label = 'SnGe NCs 4500rpm', color='orange')
plt.plot(SnGe_11000rpm['Wavelength (nm)'].values, SnGe_11000rpm['Absorbance (AU)'].values, label = 'SnGe NCs 11000rpm', color='green')
plt.legend(fontsize = 12, loc  = 1)
plt.xlim(500, 800)
plt.ylim(-0.1, 0.5)
plt.xlabel('Wavelength(nm)', fontsize=20)
plt.ylabel('Absorbance', fontsize=20)
plt.title('UV-Vis SnGe Nanocrystals', fontsize=22)
# Out:
# Text(0.5, 1.0, 'UV-Vis SnGe Nanocrystals')

# %% [markdown]
# # 02/19/2021 --> HTL on Glass

# %% [markdown]
# ## Before solvent treatment

# %%
YZ4_cntr = pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/UV-Vis/02_19_2021/YZ4_Control.CSV')
cntr = pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/UV-Vis/02_19_2021/control.CSV')
twenty_prc = pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/UV-Vis/02_19_2021/20%.CSV')
fourty_prc = pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/UV-Vis/02_19_2021/40%.CSV')
eight_mix_prc = pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/UV-Vis/02_19_2021/8%_MIX.CSV')
two_prc = pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/UV-Vis/02_19_2021/2%.CSV')
two_mix_prc = pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/UV-Vis/02_19_2021/2%_MIX.CSV')
one_mix_prc = pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/UV-Vis/02_19_2021/1%_MIX.CSV')

# %%
plt.plot(YZ4_cntr['Wavelength (nm)'].values, YZ4_cntr['Absorbance (AU)'].values, label = 'YZ4')
plt.plot(cntr['Wavelength (nm)'].values, cntr['Absorbance (AU)'].values, label ='control')
plt.plot(twenty_prc['Wavelength (nm)'].values, twenty_prc['Absorbance (AU)'].values, label = '20%')
plt.plot(fourty_prc['Wavelength (nm)'].values, fourty_prc['Absorbance (AU)'].values, label = ' 40%')
plt.plot(eight_mix_prc['Wavelength (nm)'].values, eight_mix_prc['Absorbance (AU)'].values, label = '8% Mix')
plt.plot(two_prc['Wavelength (nm)'].values, two_prc['Absorbance (AU)'].values, label = '2%')
plt.plot(two_mix_prc['Wavelength (nm)'].values, two_mix_prc['Absorbance (AU)'].values, label = '2% Mix')
plt.plot(one_mix_prc['Wavelength (nm)'].values, one_mix_prc['Absorbance (AU)'].values, label = '1% Mix')
plt.legend(fontsize = 12, loc  = 1)
plt.xlim(280, 700)
plt.ylim(-0.01, 0.050)
plt.xlabel('Wavelength(nm)')
plt.ylabel('Absorbance')
plt.title('UV-Vis before solvent treatment')
# Out:
# Text(0.5, 1.0, 'UV-Vis before solvent treatment')

# %% [markdown]
# ## Solvent treatment

# %%
YZ4_cntr_slv = pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/UV-Vis/02_19_2021/YZ4_control_SolventTreatment_DMF_DMSO.CSV')
cntr_slv = pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/UV-Vis/02_19_2021/control_SolventTreatment_DMF_DMSO.CSV')
twenty_prc_slv = pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/UV-Vis/02_19_2021/20%_SolventTreatment_DMF_DMSO.CSV')
fourty_prc_slv = pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/UV-Vis/02_19_2021/40%_SolventTreatment_DMF_DMSO.CSV')
eight_mix_prc_slv = pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/UV-Vis/02_19_2021/8%_mix_SolventTreatment_DMF_DMSO.CSV')
two_prc_slv = pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/UV-Vis/02_19_2021/2%_SolventTreatment_DMF_DMSO.CSV')
two_mix_prc_slv = pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/UV-Vis/02_19_2021/2%_mixed_SolventTreatment_DMF_DMSO.CSV')
one_mix_prc_slv = pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/UV-Vis/02_19_2021/1%_mix_SolventTreatment_DMF_DMSO.CSV')

# %%
plt.plot(YZ4_cntr_slv['Wavelength (nm)'].values, YZ4_cntr_slv['Absorbance (AU)'].values, label = 'YZ4')
plt.plot(cntr_slv['Wavelength (nm)'].values, cntr_slv['Absorbance (AU)'].values, label ='control')
plt.plot(twenty_prc_slv['Wavelength (nm)'].values, twenty_prc_slv['Absorbance (AU)'].values, label = '20%')
plt.plot(fourty_prc_slv['Wavelength (nm)'].values, fourty_prc_slv['Absorbance (AU)'].values, label = ' 40%')
plt.plot(eight_mix_prc_slv['Wavelength (nm)'].values, eight_mix_prc_slv['Absorbance (AU)'].values, label = '8% Mix')
plt.plot(two_prc_slv['Wavelength (nm)'].values, two_prc_slv['Absorbance (AU)'].values, label = '2%')
plt.plot(two_mix_prc_slv['Wavelength (nm)'].values, two_mix_prc_slv['Absorbance (AU)'].values, label = '2% Mix')
plt.plot(one_mix_prc_slv['Wavelength (nm)'].values, one_mix_prc_slv['Absorbance (AU)'].values, label = '1% Mix')
plt.legend(fontsize = 12, loc  = 1)
plt.xlim(280, 700)
plt.ylim(-0.01, 0.050)
plt.xlabel('Wavelength(nm)')
plt.ylabel('Absorbance')
plt.title('UV-Vis after solvent treatment')
# Out:
# Text(0.5, 1.0, 'UV-Vis after solvent treatment')
