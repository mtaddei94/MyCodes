# %%
import pandas as pd
import matplotlib.pyplot as plt
from customplotting.general import plot_xy, save_fig
import numpy as np

# %% [markdown]
# ## SnGe NCs

# %%
SnGe_11000rpm_em= pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/MEMC TRPL/2021_02_12_SnGeNCs_emission_exc450_470_900.CSV', skiprows= 20)
SnGe_11000rpm_em_2= pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/MEMC TRPL/2021_02_12_SnGeNCs_empectra_exc450nm_500_900_0.1s.CSV', skiprows= 20)
SnGe_11000rpm_exc_573= pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/MEMC TRPL/2021_02_12_SnGeNCs_excspectra_em573nm.CSV', skiprows= 20)
SnGe_11000rpm_exc_710= pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/MEMC TRPL/2021_02_12_SnGeNCs_excspectra_em710nm.CSV', skiprows= 20)

# %%
SnGe_11000rpm_em
# Out:
#      Detector      PMT980  Unnamed: 2
# 0       470.0  472.852295         NaN
# 1       471.0  498.934967         NaN
# 2       472.0  512.117432         NaN
# 3       473.0  505.975006         NaN
# 4       474.0  511.172668         NaN
# ..        ...         ...         ...
# 426     896.0  232.090057         NaN
# 427     897.0  123.225060         NaN
# 428     898.0  196.556702         NaN
# 429     899.0  174.251022         NaN
# 430     900.0   37.085087         NaN
#
# [431 rows x 3 columns]

# %%
plt.plot(SnGe_11000rpm_em_2['Detector'].values, SnGe_11000rpm_em_2['PMT980'].values, label = 'SnGe NCs exc 450 nm')
#plt.plot(SnGe_11000rpm_em_2['Detector'].values, SnGe_11000rpm_em_2['PMT980'].values, label = 'SnGe NCs 11000rpm')
plt.legend(fontsize = 12, loc  = 1)
plt.xlim(500, 900)
#plt.ylim(0, 30000)
plt.xlabel('Wavelength(nm)', fontsize= 20)
plt.ylabel('Counts', fontsize=20)
plt.title('PL SnGe Nanocrystals 1 day after', fontsize= 22)
# Out:
# Text(0.5, 1.0, 'PL SnGe Nanocrystals 1 day after')

# %%
plt.plot(SnGe_11000rpm_exc_573['Detector'].values, SnGe_11000rpm_exc_573['PMT980'].values, label = 'SnGe NCs em 573 nm')
plt.plot(SnGe_11000rpm_exc_710['Detector'].values, SnGe_11000rpm_exc_710['PMT980'].values, label = 'SnGe NCs em 710 nm')
plt.legend(fontsize = 12, loc  = 1)
plt.xlim(300, 700)
plt.ylim(5000, 80000)
plt.xlabel('Wavelength(nm)', fontsize= 20)
plt.ylabel('Counts', fontsize=20)
plt.title('Excitation SnGe NCs 1 day after', fontsize= 22)
# Out:
# Text(0.5, 1.0, 'Excitation SnGe NCs 1 day after')

# %% [markdown]
# ## enBr25 and Br25

# %%
enBr25_em= pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/MEMC TRPL/2021_02_12_enBr25_storeinair_em776_400_765.CSV', skiprows= 20)
enBr25_TRPL= pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/MEMC TRPL/2021_02_12_enBr25_storedinair_402nmexc_500ns_25000counts_7nmslit_TRPL.CSV', skiprows= 8)
Br25_TRPL= pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/MEMC TRPL/02_16_21_Br25air_TRPL_1MHz_0.488ns_1us.CSV', skiprows= 8)
Br25_em= pd.read_csv('/Users/margheritataddei/Desktop/Documenti/U_Washington/Ginger_Lab/2021 Data/MEMC TRPL/02_16_21_Br25 in air_exc450_500_900_0.2secdwell_5nmexc_2nmem.CSV', skiprows= 20)

# %%
Br25_em
# Out:
#      Detector      PMT980  Unnamed: 2
# 0       500.0    1.190544         NaN
# 1       501.0   -0.399711         NaN
# 2       502.0   -1.207798         NaN
# 3       503.0    1.622728         NaN
# 4       504.0    1.224420         NaN
# ..        ...         ...         ...
# 396     896.0  518.407532         NaN
# 397     897.0 -439.951447         NaN
# 398     898.0    0.000000         NaN
# 399     899.0 -620.593811         NaN
# 400     900.0 -396.417847         NaN
#
# [401 rows x 3 columns]

# %%
plt.plot(Br25_TRPL['YAxis'].values, Br25_TRPL['Counts'].values/np.max(Br25_TRPL['Counts'].values), label = 'Br25')
plt.plot(enBr25_TRPL['YAxis'].values, enBr25_TRPL['Counts'].values/np.max(enBr25_TRPL['Counts'].values), label = 'enBr25')
plt.legend(fontsize = 12, loc  = 1)
plt.xlim(0, 1000)
#plt.ylim(5000, 80000)
plt.xlabel('Time(ns)', fontsize= 20)
plt.ylabel('Counts', fontsize=20)
plt.title('Normalized TRPL enBr25 and Br25', fontsize= 22)
# Out:
# Text(0.5, 1.0, 'Normalized TRPL enBr25 and Br25')

# %%
enBr25_em
# Out:
#      Detector        PMT980  Unnamed: 2
# 0       400.0  1.734022e+06         NaN
# 1       401.0  1.796449e+06         NaN
# 2       402.0  1.823519e+06         NaN
# 3       403.0  1.865465e+06         NaN
# 4       404.0  1.858618e+06         NaN
# ..        ...           ...         ...
# 361     761.0  6.175178e+03         NaN
# 362     762.0  5.161591e+03         NaN
# 363     763.0  3.912073e+03         NaN
# 364     764.0  6.014297e+03         NaN
# 365     765.0  1.450202e+04         NaN
#
# [366 rows x 3 columns]

# %%
plt.plot(Br25_em['Detector'].values, Br25_em['PMT980'].values, label = 'Br25')
plt.plot(enBr25_em['Detector'].values, enBr25_em['PMT980'].values, label = 'enBr25')
plt.legend(fontsize = 12, loc  = 1)
plt.xlim(400, 850)
#plt.ylim(5000, 80000)
plt.xlabel('Wavelength(nm)', fontsize= 20)
plt.ylabel('PL Intensity', fontsize=20)
plt.title('PL enBr25 and Br25', fontsize= 22)
# Out:
# Text(0.5, 1.0, 'PL enBr25 and Br25')
